# %%
from sudoku_csp import SudokuCSP, generateSudoku
import numpy as np

# %% [markdown]
# # Prezentační notebook

# %% [markdown]
# ####  Sudoku 4 x 4

# %%
sudoku, solved = generateSudoku(size=4, difficulty=0.8) # 0.1 s
SudokuCSP(sudoku)

# %% [markdown]
# ### Sudoku 9 x 9

# %%
sudoku, solved = generateSudoku(size=9, difficulty=0.2) # 0.6 s
SudokuCSP(sudoku)

# %%
sudoku, solved = generateSudoku(size=9, difficulty=0.5) # 0.5 s
SudokuCSP(sudoku)

# %%
sudoku, solved = generateSudoku(size=9, difficulty=0.9) # 0.5s
SudokuCSP(sudoku)

# %% [markdown]
# ### Sudoku 16 x 16

# %%
sudoku, solved = generateSudoku(size=16, difficulty=0.5) # 1.5s
SudokuCSP(sudoku)

# %%
sudoku, solved = generateSudoku(size=16, difficulty=0.5) # 1.7 s
SudokuCSP(sudoku)

# %%
sudoku, solved = generateSudoku(size=16, difficulty=0.6) # 86 s
SudokuCSP(sudoku)

# %% [markdown]
# ### Sudoku 25 x 25

# %%
sudoku, solved = generateSudoku(size=25, difficulty=0.2) # 18.3 s
SudokuCSP(sudoku) # 3.3s

# %%
sudoku, solved = generateSudoku(size=25, difficulty=0.3) # 20 s

# %%
SudokuCSP(sudoku) # > 4 s
